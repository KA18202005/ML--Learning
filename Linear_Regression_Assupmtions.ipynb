# %% [markdown]
# <a href="https://colab.research.google.com/github/KA18202005/ML--Learning/blob/main/Linear_Regression_Assupmtions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('data.csv')
df
# Out:
#      feature1  feature2  feature3     target
# 0   -0.570563  1.420342  0.495580  -9.763182
# 1   -0.990563  0.556965  1.045064 -24.029355
# 2   -0.674728  0.150617  1.774645  45.616421
# 3    0.388250 -0.387127 -0.110229  34.135737
# 4    1.167882 -0.024104  0.145063  86.663647
# ..        ...       ...       ...        ...
# 195  0.255081 -0.231497 -0.239632  38.067836
# 196  0.276068 -0.648411 -0.077441  12.812755
# 197  0.122250 -1.157383  0.765721  70.454115
# 198 -0.914822 -0.897140 -0.784205 -93.235783
# 199  0.090717 -2.217418 -0.892406 -42.772129
#
# [200 rows x 4 columns]

# %%
X = df.iloc[:,0:3].values
y = df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.1,random_state=1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
residual = y_test - y_pred

# %%
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3, figsize=(12, 2.5))

ax1.scatter(df['feature1'], df['target'])
ax1.set_title("Feature1")
ax2.scatter(df['feature2'], df['target'])
ax2.set_title("Feature2")
ax3.scatter(df['feature3'], df['target'])
ax3.set_title("Feature3")

plt.show()

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor
vif = []
for i in range(X_train.shape[1]):
    vif.append(variance_inflation_factor(X_train, i))

# %%
pd.DataFrame({'vif' : vif}, index=df.columns[0:3]).T
# Out:
#      feature1  feature2  feature3
# vif   1.00173  1.009067  1.010293

# %%
sns.heatmap(df.iloc[:,0:3].corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.displot(residual,kind='kde')

# %%
import scipy as sp

fig, ax = plt.subplots(figsize=(6,4))
sp.stats.probplot(residual, plot=ax, fit=True)

plt.show()

# %%
plt.scatter(y_pred,residual)

# %%
plt.plot(residual)
